# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import StratifiedKFold

# %%
IMAGE_SIZE = [224, 224]
train_path="../pokemon_dataset/"

# %%
train = []
for file in os.listdir(os.path.join(train_path, 'train/pikachu')):
    train.append(['train/pikachu/{}'.format(file), 'pikachu'])

for file in os.listdir(os.path.join(train_path, 'train/raichu')):
    train.append(['train/raichu/{}'.format(file), 'raichu'])
    
train = pd.DataFrame(train, columns=['file', 'class_id'])

train = train.sample(frac=1).reset_index(drop=True)
#train = train.sample(80).reset_index(drop=True)
#print(train)

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras import Sequential

# %%
model = Sequential()
model.add(Conv2D(32, (5,5),padding='valid',activation='relu',input_shape=(224,224,4)))
model.add(MaxPooling2D(pool_size=(4,4)))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(2,activation='softmax'))

# %%
from keras.losses import CategoricalCrossentropy
model.compile(
  optimizer='adam',
  loss=CategoricalCrossentropy(),
  metrics=[tf.keras.metrics.Precision()])

# %%
from keras.preprocessing.image import ImageDataGenerator
# create generator
datagen = ImageDataGenerator(rescale = 1./255,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True,
                             vertical_flip=True,
                             rotation_range=30)

# %%
from sklearn.model_selection import StratifiedKFold

strtfdKFold = StratifiedKFold(n_splits=10)
t = train.class_id
kfold = strtfdKFold.split(train, t)
scores = []
tot_score = 0

for k, (train_idx, test_idx) in enumerate(kfold):
    # prepare an iterators for each dataset
    train_data = train.loc[train_idx]
    test_data = train.loc[test_idx]
    train_it = datagen.flow_from_dataframe(dataframe = train_data,
                                       directory=train_path, 
                                       class_mode='categorical',
                                       x_col="file",
                                       y_col="class_id",
                                       target_size=(224, 224),
                                       color_mode='rgba',
                                       batch_size=2,
                                       seed=7)
    test_it = datagen.flow_from_dataframe(dataframe = test_data,  
                                       directory=train_path,
                                       class_mode='categorical',
                                       x_col="file",
                                       y_col="class_id",
                                       target_size=(224, 224),
                                       color_mode='rgba',
                                       batch_size=2,
                                       seed=7)

    model.fit(train_it,
            validation_data = test_it,
            epochs = 1)
    scores = model.evaluate(test_it)
    tot_score += scores[1]*100
    print("Accuarcy %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

print('\n\nCross-Validation accuracy: %.3f' %(tot_score/5))
# Out:
# Found 127 validated image filenames belonging to 2 classes.
# Found 15 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 64/64 [==============================] - 17s 258ms/step - loss: 2.6989 - precision_17: 0.4646 - val_loss: 0.6924 - val_precision_17: 0.4000
# Epoch 2/5
# 64/64 [==============================] - 17s 270ms/step - loss: 0.6871 - precision_17: 0.5118 - val_loss: 0.7061 - val_precision_17: 0.4000
# Epoch 3/5
# 64/64 [==============================] - 18s 277ms/step - loss: 0.7883 - precision_17: 0.5276 - val_loss: 0.6644 - val_precision_17: 0.8000
# Epoch 4/5
# 64/64 [==============================] - 16s 250ms/step - loss: 0.6722 - precision_17: 0.6614 - val_loss: 0.7188 - val_precision_17: 0.6000
# Epoch 5/5
# 64/64 [==============================] - 15s 238ms/step - loss: 0.6849 - precision_17: 0.6063 - val_loss: 0.7535 - val_precision_17: 0.4000
# 8/8 [==============================] - 0s 57ms/step - loss: 0.7059 - precision_17: 0.6667
# Accuarcy precision_17: 66.67%
# Found 127 validated image filenames belonging to 2 classes.
# Found 15 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 64/64 [==============================] - 16s 247ms/step - loss: 0.6804 - precision_17: 0.5748 - val_loss: 0.6710 - val_precision_17: 0.8000
# Epoch 2/5
# 64/64 [==============================] - 16s 243ms/step - loss: 0.6787 - precision_17: 0.6299 - val_loss: 0.6892 - val_precision_17: 0.5333
# Epoch 3/5
# 64/64 [==============================] - 19s 295ms/step - loss: 0.7060 - precision_17: 0.6063 - val_loss: 0.6935 - val_precision_17: 0.5333
# Epoch 4/5
# 64/64 [==============================] - 17s 259ms/step - loss: 0.6735 - precision_17: 0.5591 - val_loss: 0.6670 - val_precision_17: 0.8667
# Epoch 5/5
# 64/64 [==============================] - 17s 268ms/step - loss: 0.6906 - precision_17: 0.5669 - val_loss: 0.7182 - val_precision_17: 0.5333
# 8/8 [==============================] - 1s 65ms/step - loss: 0.7229 - precision_17: 0.5333
# Accuarcy precision_17: 53.33%
# Found 128 validated image filenames belonging to 2 classes.
# Found 14 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 64/64 [==============================] - 17s 267ms/step - loss: 0.6859 - precision_17: 0.5469 - val_loss: 0.5989 - val_precision_17: 0.6429
# Epoch 2/5
# 64/64 [==============================] - 18s 274ms/step - loss: 0.6713 - precision_17: 0.6094 - val_loss: 0.5806 - val_precision_17: 0.7143
# Epoch 3/5
# 64/64 [==============================] - 17s 259ms/step - loss: 0.7209 - precision_17: 0.5859 - val_loss: 0.5777 - val_precision_17: 0.7143
# Epoch 4/5
# 64/64 [==============================] - 17s 258ms/step - loss: 0.6951 - precision_17: 0.6484 - val_loss: 0.7364 - val_precision_17: 0.5714
# Epoch 5/5
# 64/64 [==============================] - 17s 266ms/step - loss: 0.6599 - precision_17: 0.6172 - val_loss: 0.7210 - val_precision_17: 0.7143
# 7/7 [==============================] - 0s 60ms/step - loss: 0.5940 - precision_17: 0.6429
# Accuarcy precision_17: 64.29%
# Found 128 validated image filenames belonging to 2 classes.
# Found 14 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 64/64 [==============================] - 17s 264ms/step - loss: 0.6209 - precision_17: 0.6562 - val_loss: 0.5413 - val_precision_17: 0.8571
# Epoch 2/5
# 64/64 [==============================] - 16s 252ms/step - loss: 0.6702 - precision_17: 0.6016 - val_loss: 0.6957 - val_precision_17: 0.5000
# Epoch 3/5
# 64/64 [==============================] - 16s 254ms/step - loss: 0.6721 - precision_17: 0.5703 - val_loss: 0.6960 - val_precision_17: 0.4286
# Epoch 4/5
# 64/64 [==============================] - 16s 252ms/step - loss: 0.6797 - precision_17: 0.6172 - val_loss: 0.6603 - val_precision_17: 0.5714
# Epoch 5/5
# 64/64 [==============================] - 16s 254ms/step - loss: 0.7730 - precision_17: 0.6016 - val_loss: 0.6967 - val_precision_17: 0.5000
# 7/7 [==============================] - 1s 68ms/step - loss: 0.6927 - precision_17: 0.5000
# Accuarcy precision_17: 50.00%
# Found 128 validated image filenames belonging to 2 classes.
# Found 14 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 64/64 [==============================] - 16s 257ms/step - loss: 0.6499 - precision_17: 0.6094 - val_loss: 0.7389 - val_precision_17: 0.4286
# Epoch 2/5
# 64/64 [==============================] - 16s 257ms/step - loss: 0.7054 - precision_17: 0.6250 - val_loss: 0.6977 - val_precision_17: 0.5000
# Epoch 3/5
# 64/64 [==============================] - 17s 259ms/step - loss: 0.6810 - precision_17: 0.5312 - val_loss: 0.6871 - val_precision_17: 0.5000
# Epoch 4/5
# 64/64 [==============================] - 17s 263ms/step - loss: 0.6704 - precision_17: 0.5547 - val_loss: 0.6918 - val_precision_17: 0.4286
# Epoch 5/5
# 64/64 [==============================] - 18s 273ms/step - loss: 0.6845 - precision_17: 0.5312 - val_loss: 0.6902 - val_precision_17: 0.5000
# 7/7 [==============================] - 0s 67ms/step - loss: 0.6875 - precision_17: 0.5000
# Accuarcy precision_17: 50.00%
# Found 128 validated image filenames belonging to 2 classes.
# Found 14 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 64/64 [==============================] - 17s 266ms/step - loss: 0.6858 - precision_17: 0.5234 - val_loss: 0.6562 - val_precision_17: 0.5714
# Epoch 2/5
# 64/64 [==============================] - 17s 268ms/step - loss: 0.6828 - precision_17: 0.5547 - val_loss: 0.6293 - val_precision_17: 0.6429
# Epoch 3/5
# 64/64 [==============================] - 17s 267ms/step - loss: 0.6449 - precision_17: 0.5781 - val_loss: 3.9673 - val_precision_17: 0.5000
# Epoch 4/5
# 64/64 [==============================] - 17s 262ms/step - loss: 0.8183 - precision_17: 0.5234 - val_loss: 0.6397 - val_precision_17: 0.5714
# Epoch 5/5
# 64/64 [==============================] - 16s 255ms/step - loss: 0.7713 - precision_17: 0.5234 - val_loss: 0.6459 - val_precision_17: 0.5714
# 7/7 [==============================] - 0s 56ms/step - loss: 0.6755 - precision_17: 0.5000
# Accuarcy precision_17: 50.00%
# Found 128 validated image filenames belonging to 2 classes.
# Found 14 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 64/64 [==============================] - 17s 259ms/step - loss: 0.6793 - precision_17: 0.5391 - val_loss: 0.6940 - val_precision_17: 0.5000
# Epoch 2/5
# 64/64 [==============================] - 16s 256ms/step - loss: 0.6677 - precision_17: 0.5312 - val_loss: 0.6941 - val_precision_17: 0.5000
# Epoch 3/5
# 64/64 [==============================] - 17s 266ms/step - loss: 0.6737 - precision_17: 0.5391 - val_loss: 0.6936 - val_precision_17: 0.5000
# Epoch 4/5
# 64/64 [==============================] - 17s 257ms/step - loss: 0.6693 - precision_17: 0.5391 - val_loss: 0.6931 - val_precision_17: 0.5000
# Epoch 5/5
# 64/64 [==============================] - 17s 261ms/step - loss: 0.6592 - precision_17: 0.5391 - val_loss: 0.6933 - val_precision_17: 0.5000
# 7/7 [==============================] - 0s 56ms/step - loss: 0.6913 - precision_17: 0.5714
# Accuarcy precision_17: 57.14%
# Found 128 validated image filenames belonging to 2 classes.
# Found 14 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 64/64 [==============================] - 17s 264ms/step - loss: 0.6727 - precision_17: 0.5469 - val_loss: 0.7137 - val_precision_17: 0.5000
# Epoch 2/5
# 64/64 [==============================] - 17s 261ms/step - loss: 0.7180 - precision_17: 0.5312 - val_loss: 0.6937 - val_precision_17: 0.5000
# Epoch 3/5
# 64/64 [==============================] - 17s 268ms/step - loss: 0.6957 - precision_17: 0.5781 - val_loss: 0.7150 - val_precision_17: 0.5000
# Epoch 4/5
# 64/64 [==============================] - 16s 257ms/step - loss: 0.6646 - precision_17: 0.6250 - val_loss: 0.7742 - val_precision_17: 0.5000
# Epoch 5/5
# 64/64 [==============================] - 17s 272ms/step - loss: 0.7548 - precision_17: 0.6016 - val_loss: 0.6949 - val_precision_17: 0.5000
# 7/7 [==============================] - 0s 49ms/step - loss: 0.6947 - precision_17: 0.5000
# Accuarcy precision_17: 50.00%
# Found 128 validated image filenames belonging to 2 classes.
# Found 14 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 64/64 [==============================] - 16s 257ms/step - loss: 0.6621 - precision_17: 0.5312 - val_loss: 0.7279 - val_precision_17: 0.4286
# Epoch 2/5
# 52/64 [=======================>......] - ETA: 2s - loss: 0.6724 - precision_17: 0.5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21212\2150471192.py in <module>
#      31                                        seed=7)
#      32
# ---> 33     model.fit(train_it,
#      34             validation_data = test_it,
#      35             epochs = 5)
#
# c:\Users\meng9\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\meng9\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# c:\Users\meng9\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\meng9\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\meng9\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\meng9\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# c:\Users\meng9\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\meng9\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# c:\Users\meng9\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
